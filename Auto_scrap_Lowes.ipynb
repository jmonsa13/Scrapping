# %% [markdown]
# <a href="https://colab.research.google.com/github/jmonsa13/Scrapping/blob/main/Auto_scrap_Lowes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Main Code

# %%
# Python project for pricing scripping of different sites
# Creado por: Juan Monsalvo

# FOR Lowes
# ----------------------------------------------------------------------------------------------------------------------
# Libraries import
# ----------------------------------------------------------------------------------------------------------------------
import datetime
import numpy as np
import pandas as pd
import re
import json
import requests
import time
import os

from google.colab import drive
drive.mount('/drive')

# ----------------------------------------------------------------------------------------------------------------------
# Configuration and Global Variables
# ----------------------------------------------------------------------------------------------------------------------
# Header for beautiful soup
headers = {
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:88.0) Gecko/20100101 Firefox/88.0",
    'Cookie': 'sn=2348;'
}
cookies = {"sn":"2348", 'region' : 'east'} # Central Charlotte 2348

# Path definition of the .csv file
fecha = datetime.datetime.today()

# Sheet Mansfield
sheet_name_mansfield = 'Mansfield'
output_path_toilet_mansfield = '/drive/MyDrive/00_SCRAPPING/XX_Data/Lowes_Mansfield-' + str(fecha.year) + '_' + \
                               str(fecha.month) + '.csv'

# Sheet Competitors
sheet_name_competitor = 'Competitors'
output_path_toilet_competitor = '/drive/MyDrive/00_SCRAPPING/XX_Data/Lowes_Competitors-' + str(fecha.year) + '_' + \
                                str(fecha.month) + '.csv'

# Path for loading the URL sites
url_path_toilet = '/drive/MyDrive/00_SCRAPPING/XX_URL/Lowes_Database.xlsx'

product_path =  [[url_path_toilet, output_path_toilet_mansfield, sheet_name_mansfield],
                 [url_path_toilet, output_path_toilet_competitor, sheet_name_competitor]]

# Number of retry
NUM_RETRIES = 5

# Waiting time between request
delays = [1, 4, 8, 2, 5, 3]

# ----------------------------------------------------------------------------------------------------------------------
# Function Definition
# ----------------------------------------------------------------------------------------------------------------------
def lowes_data(elem, data):
    """
    Programa que toma la información general de una pagina de producto del market place de Ferguson
    """
    item_id = elem['Link'].split("/")[-1]
    # print(json.dumps(data["productDetails"][item_id], indent=4, sort_keys=True))

    # Collecting the name and product type
    brand_name = elem["Fabricante"]
    product_name = elem["Description"]
    product_subcategory = elem["Subcategory"]
    product_format = elem["Tipo"]
    linea_name = elem["Linea"]
    price_type = elem["Price Type"]

    # Collecting the price
    try:
      price_clean = float(data["productDetails"][item_id]["price"]["analyticsData"]["sellingPrice"])
    except:
      price_clean = ""

    try:
      was_price_clean = float(data["productDetails"][item_id]["price"]["analyticsData"]["wasPrice"])
    except:
      was_price_clean = ""

    try:
      offert_price = float(data["productDetails"][item_id]["offerPromotions"]["offerPrice"])
    except:
      offert_price = ""

    # print("PromoMsg:", data["productDetails"][item_id]["offerPromotions"]["displayPromoMsg"])
    # print("Currency:", data["productDetails"][item_id]["price"]["newPrice"]["price"]["currency"])

    # Collecting the sku of product
    sku_ref = data["productDetails"][item_id]["product"]["omniItemId"]
    item_ref = data["productDetails"][item_id]["product"]["itemNumber"]
    model_ref = data["productDetails"][item_id]["product"]["modelId"]

    # Collecting the image
    aux_url_img = data["productDetails"][item_id]["product"]["imageUrls"][0]["value"]
    url_img = 'https://mobileimages.lowes.com' + aux_url_img

    # Stock
    try:
      aux_stock = int(data["productDetails"][item_id]["itemInventory"]["totalAvailableQty"])
      if aux_stock >= 0:
        stock = "Si"
      else:
        stock = "No"
    except:
      stock = "No Disponible"
    # ------------------------------------------------------------------------------------------------------------------
    # Message display
    print("Recopilando la información de {}".format(elem["Link"]))
    print("La marca es la: {}".format(brand_name))
    print("El sanitario es el: {}".format(product_name))
    print("El tipo de producto es un: {}".format(product_format))
    print("El sku es el: {}".format(sku_ref))
    print("El item es el: {}".format(item_ref))
    print("El model es el: {}".format(model_ref))
    print("El precio actual es: {} USD".format(price_clean))
    print("El precio anterior es: {} USD".format(was_price_clean))
    print("El precio con descuento especial es: {} USD".format(offert_price))
    print("Inventario:{}".format(stock))
    print(url_img)
    print("\n")
    # ------------------------------------------------------------------------------------------------------------------

    # Appending the item in a list
    information = [datetime.datetime.today().date(), brand_name, elem["Sku"],
                   linea_name, product_subcategory, product_format, elem["Rough in"], elem["Bowl Height"], elem["Asiento"],
                   elem["Capacidad"], product_name, price_type, price_clean, was_price_clean, offert_price,
                   "USD", "lowes.com", "Si", elem["Link"], url_img]

    return information


# ----------------------------------------------------------------------------------------------------------------------
# Main code
# ----------------------------------------------------------------------------------------------------------------------
# Scrapping the information of every url
for product_type, output_path, sheet_name  in product_path:
    # Reading .xlsx file with url list
    file_df = pd.read_excel(product_type, sheet_name=sheet_name)

    # Keeping just the row with links
    product_df = file_df[file_df['Link'].notna()]

    # Scrapping the information of every product
    datos = []
    for index, elem in product_df.iterrows():
      for i in range(NUM_RETRIES):
          # Random Wait between request
          delay = np.random.choice(delays)
          time.sleep(delay)
          try:
              response = requests.get(elem["Link"], headers=headers, cookies=cookies)
              # response = requests.get(elem["Link"], headers=headers, meta=meta)


              print("Intento numero {}".format(i))
              print(response)
              if response.status_code in [200, 404]:
                  # escape for loop if the API returns a successful response
                  break
          except requests.exceptions.ConnectionError:
              response = ''
              print("ConnectionError")

      # parse data if 200 status code (successful response)
      if response.status_code == 200:
          # Parse data with json
          t = response.text
          data = re.search(r"window\['__PRELOADED_STATE__'\] = (\{.*?\})<", t)
          data = json.loads(data.group(1))
          
          # Uncomment to print all data:
          # print(json.dumps(data, indent=4))

          # Getting the information from the website
          toilet_information = lowes_data(elem, data)
          datos.append(toilet_information)

    # Creating the dataframe
    df = pd.DataFrame(datos, columns=["Fecha", "Fabricante", "SKU", "Linea", 'Subcategoria', "Tipo", "Rough_In",
                                     "Bowl_Height", "Asiento", "Capacidad_(Gpl)", "Producto",
                                     "Price_Type", "Precio_Consumidor", "Precio_Anterior", "Precio_Promocion", "Moneda",
                                     "Market_Place", "Stock", "URL", "Image_url"])
    
    # Saving the file in a .csv file
    df.to_csv(output_path, mode='a', header=not os.path.exists(output_path), index=False)
# Out:
# Mounted at /drive
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-Alto-174-1-28-Round-SmartHeight-8482-Toilet-Combination/5002186849
# La marca es la: Mansfield
# El sanitario es el: Alto CTK 12 ADA RF 1,28 gpf
# El tipo de producto es un: CTK
# El sku es el: 5002186849
# El item es el: 4144313
# El model es el: 117-3173
# El precio actual es: 209.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 198.55 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/2015302a-710d-4a0a-82c0-b499ddf87b1e/44125209.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-Alto-White-WaterSense-Elongated-Comfort-Height-2-Piece-Vitreous-China-Toilet-12-in-Rough-In-Size-ADA-Compliant/1002970010
# La marca es la: Mansfield
# El sanitario es el: Alto CTK 12 ADA RF 1,28 gpf
# El tipo de producto es un: CTK
# El sku es el: 1002970010
# El item es el: 2412589
# El model es el: 5117CTK
# El precio actual es: 129.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 122.55 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/3bbeb072-6dce-4011-b628-1787e4aeb133/15195975.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-Barrett-White-Elongated-Chair-Height-2-Piece-WaterSense-Toilet-12-in-Rough-In-Size-ADA-Compliant/5005480077
# La marca es la: Mansfield
# El sanitario es el: Barret CTK 12 ADA EL 1,28 gpf
# El tipo de producto es un: CTK
# El sku es el: 5005480077
# El item es el: 4144305
# El model es el: 4115-3106
# El precio actual es: 324.87 USD
# El precio anterior es: 344.0 USD
# El precio con descuento especial es: 308.6265 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/7f8d84a1-e7e0-45b3-bd8f-f3734e1ac767/44125204.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-Brentwood-White-Elongated-Comfort-Height-2-Piece-Toilet-12-in-Rough-In-Size-ADA-Compliant/5001176259
# La marca es la: Mansfield
# El sanitario es el: Brentwood CTK 12 ADA EL 1,6 gpf
# El tipo de producto es un: CTK
# El sku es el: 5001176259
# El item es el: 2607511
# El model es el: 5147CTK
# El precio actual es: 199.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 189.05 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/22847ff2-bb79-412a-95bc-a1a62b02d333/16021059.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-Brentwood-White-WaterSense-Elongated-Comfort-Height-2-Piece-Toilet-12-in-Rough-In-Size-ADA-Compliant/5001176257
# La marca es la: Mansfield
# El sanitario es el: Brentwood CTK 12 ADA EL 1,28 gpf
# El tipo de producto es un: CTK
# El sku es el: 5001176257
# El item es el: 2607510
# El model es el: 5148CTK
# El precio actual es: 199.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 189.05 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/da780978-50d4-4904-ac8f-98533e3424c8/16001442.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-Broadway-8482-1-28-Elongated-SmartHeight-8482-Complete-Toilet-Kit/5002187709
# La marca es la: Mansfield
# El sanitario es el: Broadway CTK 12 ADA EL 1,28 gpf
# El tipo de producto es un: CTK
# El sku es el: 5002187709
# El item es el: 4144303
# El model es el: 710CTK
# El precio actual es: 529.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 502.55 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/ea8ce552-d36a-494f-b4b4-54dfc887f713/44133247.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-Cascade-White-WaterSense-Elongated-Comfort-Height-2-Piece-Toilet-12-in-Rough-In-Size-ADA-Compliant/1003164754
# La marca es la: Mansfield
# El sanitario es el: Cascade CTK 12 ADA EL 1,28 gpf
# El tipo de producto es un: CTK
# El sku es el: 1003164754
# El item es el: 2626661
# El model es el: 5817CTK
# El precio actual es: 89.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 84.55 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/8577e8de-2546-42b9-b815-9cb954e0e391/16146982.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-Denali-White-WaterSense-Elongated-Comfort-Height-2-Piece-Vitreous-China-Toilet-12-in-Rough-In-Size-with-Slow-Close-ADA-Compliant/1002969006
# La marca es la: Mansfield
# El sanitario es el: Denali CTK 12 ADA EL 1,28 gpf
# El tipo de producto es un: CTK
# El sku es el: 1002969006
# El item es el: 2412593
# El model es el: 5916CTK
# El precio actual es: 209.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 198.55 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/6259343e-1a83-4c4b-a103-7cb3252a41c7/15195978.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-Elementary-174-1-28-Round-Juvenile-Toilet-Combination/5002178749
# La marca es la: Mansfield
# El sanitario es el: Elementary CTK 10 Juvenile - children RF 1,28 gpf
# El tipo de producto es un: CTK
# El sku es el: 5002178749
# El item es el: 4141020
# El model es el: 4326-4321
# El precio actual es: 347.94 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 330.543 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/c7e7920a-e663-4e97-8af1-ea3d6c751f52/44105379.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-Enso-174-Dual-Flush-Elongated-SmartHeight-8482-Toilet-Combination/5003105879
# La marca es la: Mansfield
# El sanitario es el: Enso CTK 12 Std - Smartheight EL 1,1 gpf/1,6 gpf
# El tipo de producto es un: CTK
# El sku es el: 5003105879
# El item es el: 4144306
# El model es el: 177-178
# El precio actual es: 564.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 535.8 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/f022bfc1-3cbc-4903-b1e9-4d907b5ee26d/44200117.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-Maverick-8482-1-0-Elongated-SmartHeight-8482-Toilet-Combination/5002187719
# La marca es la: Mansfield
# El sanitario es el: Maverick CTK 12 Std - Smartheight EL 1
# El tipo de producto es un: CTK
# El sku es el: 5002187719
# El item es el: 4144314
# El model es el: 1014-1012
# El precio actual es: 264.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 250.8 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/1f0a51b2-770d-45f2-adb0-fb5bb8cc2f9f/44133262.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-Nyren-8482-Dual-Flush-Elongated-Tankless-Smart-Toilet/5003101913
# La marca es la: Mansfield
# El sanitario es el: Nyren CTK 12 Std EL 1,6 gpf
# El tipo de producto es un: CTK
# El sku es el: 5003101913
# El item es el: 4144304
# El model es el: 760
# El precio actual es: 2609.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 2478.55 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/c660ce1b-58ed-4d10-b5ad-fafe92b96a2a/44200122.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-Pro-Fit-White-WaterSense-Elongated-Standard-Height-2-Piece-Toilet-12-in-Rough-In-Size/5001993525
# La marca es la: Mansfield
# El sanitario es el: Pro-Fit CTK 12 Std EL 1,28 gpf
# El tipo de producto es un: CTK
# El sku es el: 5001993525
# El item es el: 3488680
# El model es el: 5135CTK
# El precio actual es: 129.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 122.55 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/e6faab75-5c04-4538-b2b8-7c14f7d9cf7b/41858885.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-QuantumOne-8482-1-0-Elongated-SmartHeight-8482-Toilet-Combination/5002187713
# La marca es la: Mansfield
# El sanitario es el: Quantum One CTK 12 ADA EL 1
# El tipo de producto es un: CTK
# El sku es el: 5002187713
# El item es el: 4144309
# El model es el: 148-153
# El precio actual es: 644.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 611.8 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/eb171853-a4e2-4eab-a191-9d542e896eb8/44133255.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-QuantumOne-8482-1-0-Elongated-Rear-Outlet-Wall-Mount-Toilet-Combination/5002186843
# La marca es la: Mansfield
# El sanitario es el: Quantum One CTK 12 ADA EL 1
# El tipo de producto es un: CTK
# El sku es el: 5002186843
# El item es el: 4144311
# El model es el: 144-153
# El precio actual es: 964.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 915.8 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/52a611f4-3b97-4ca6-aa55-214e989cb735/44125200.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-QuantumOne-8482-1-0-Elongated-Rear-Outlet-Floor-Mount-Toilet-Combination/5002187715
# La marca es la: Mansfield
# El sanitario es el: Quantum One CTK 12 ADA EL 1
# El tipo de producto es un: CTK
# El sku es el: 5002187715
# El item es el: 4144308
# El model es el: 149-153
# El precio actual es: 489.51 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 465.0345 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/f0a91abf-c110-46b9-9983-c2b91bd42250/44133253.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-Summit-White-WaterSense-Dual-Flush-Elongated-Comfort-Height-2-Piece-Toilet-12-in-Rough-In-Size-ADA-Compliant/5001993529
# La marca es la: Mansfield
# El sanitario es el: Summit CTK 12 ADA EL 1,1 gpf/1,6 gpf
# El tipo de producto es un: CTK
# El sku es el: 5001993529
# El item es el: 3637701
# El model es el: 5384DFCTK
# El precio actual es: 209.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 198.55 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/cdbe134f-ef0d-4f7c-be82-22ecc940e192/41858886.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-Summit-White-WaterSense-Elongated-Comfort-Height-2-Piece-Toilet-10-in-Rough-In-Size-ADA-Compliant/5001993545
# La marca es la: Mansfield
# El sanitario es el: Summit CTK 10 ADA EL 1,28 gpf
# El tipo de producto es un: CTK
# El sku es el: 5001993545
# El item es el: 3637702
# El model es el: 5385CTK
# El precio actual es: 219.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 208.05 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/da94b8f0-fd32-4bea-a800-55966bee3829/41928885.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-Summit-White-WaterSense-Elongated-Comfort-Height-2-Piece-Vitreous-China-Toilet-12-in-Rough-In-Size-with-Slow-Close-ADA-Compliant/1002969002
# La marca es la: Mansfield
# El sanitario es el: Summit CTK 12 ADA EL 1,28 gpf
# El tipo de producto es un: CTK
# El sku es el: 1002969002
# El item es el: 2412592
# El model es el: 5384CTK
# El precio actual es: 189.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 179.55 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/87fd9cc1-467d-4d76-bc37-fe50d96d101e/15195969.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-Summit-174-1-28-Elongated-SmartHeight-8482-Toilet-Combination/5002189019
# La marca es la: Mansfield
# El sanitario es el: Summit CTK 12 ADA EL 1,28 gpf
# El tipo de producto es un: CTK
# El sku es el: 5002189019
# El item es el: 4144315
# El model es el: 384-387RH
# El precio actual es: 224.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 212.8 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/3596fbb3-a979-4772-9353-261a8c1721e6/44137314.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-Summit-174-1-28-Round-Toilet-Combination/5002187711
# La marca es la: Mansfield
# El sanitario es el: Summit CTK 12 Std RF 1,28 gpf
# El tipo de producto es un: CTK
# El sku es el: 5002187711
# El item es el: 4144302
# El model es el: 380-387
# El precio actual es: 244.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 231.8 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/0df73309-6e38-4083-b634-71268c8f88cc/44133245.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-Vanquish-White-WaterSense-Elongated-Comfort-Height-2-Piece-Vitreous-China-Toilet-12-in-Rough-In-Size-with-Slow-Close-ADA-Compliant/1002969010
# La marca es la: Mansfield
# El sanitario es el: Vanquish CTK 12 ADA EL 1,28 gpf
# El tipo de producto es un: CTK
# El sku es el: 1002969010
# El item es el: 2412594
# El model es el: 5988CTK
# El precio actual es: 249.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 236.55 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/e787c458-1a64-4157-b659-b0d381836714/15230775.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-VX1-1-28-Round-Complete-Toilet-Kit/1002959738
# La marca es la: Mansfield
# El sanitario es el: VX1 CTK 12 Std RF 1,28 gpf
# El tipo de producto es un: CTK
# El sku es el: 1002959738
# El item es el: 2626662
# El model es el: 5030CTK
# El precio actual es: 79.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 75.05 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/722dc1a7-1e05-49a7-aa56-0faf40b8efd2/16145498.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-Pro-Fit-White-WaterSense-Round-Standard-Height-2-Piece-Toilet-12-in-Rough-In-Size/5001993533
# La marca es la: Mansfield
# El sanitario es el: Pro-Fit CTK 12 Std RF 1,28 gpf
# El tipo de producto es un: CTK
# El sku es el: 5001993533
# El item es el: 3488679
# El model es el: 5130CTK
# El precio actual es: 139.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 132.05 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/fe01ab40-86c4-4fbb-aec0-9c67824cad98/41858876.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-Summit-White-WaterSense-Round-Comfort-Height-2-piece-Toilet-12-in-Rough-In-Size/1002666246
# La marca es la: Mansfield
# El sanitario es el: Summit Round CTK (Ada Compliant)
# El tipo de producto es un: CTK
# El sku es el: 1002666246
# El item es el: 2412591
# El model es el: 5388CTK
# El precio actual es: 159.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 151.05 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/72f9f589-ff7d-4f1c-a0e7-0f9dca6041d0/15416222.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Mansfield-Denali-Bone-WaterSense-Elongated-Comfort-Height-2-Piece-Toilet-12-in-Rough-In-Size-ADA-Compliant/5002069775
# La marca es la: Mansfield
# El sanitario es el: Denali Elongated CTK (Ada Compliant)
# El tipo de producto es un: CTK
# El sku es el: 5002069775
# El item es el: 3637700
# El model es el: 5916BNCTK
# El precio actual es: 239.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 227.05 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/9257a5af-ab97-4d9c-8447-17de8012a6dc/41858902.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/KOHLER-Highline-Curve-White-WaterSense-Elongated-Chair-Height-2-Piece-Toilet-12-in-Rough-In-Size/1001097304
# La marca es la: KOHLER
# El sanitario es el: Highline Elongated CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 1001097304
# El item es el: 1323429
# El model es el: K-78276-0
# El precio actual es: 219.0 USD
# El precio anterior es: 249.0 USD
# El precio con descuento especial es: 208.05 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/b6e54c51-a71e-4ef4-8494-07a9fff0024f/11255262.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/KOHLER-Cimarron-White-WaterSense-Elongated-Comfort-Height-2-Piece-Toilet-12-in-Rough-In-Size-ADA-Compliant/5001954253
# La marca es la: KOHLER
# El sanitario es el: Cimarron Elongated CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 5001954253
# El item es el: 3629216
# El model es el: 31658-0
# El precio actual es: 299.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 284.05 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/03a71c94-b817-42eb-886a-e6be22be7b62/42700491.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/American-Standard-Clean-White-WaterSense-Elongated-Chair-Height-2-Piece-Toilet-12-in-Rough-In-Size/1000247233
# La marca es la: American Standard
# El sanitario es el: Clean White Elongated CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 1000247233
# El item es el: 88575
# El model es el: 2514101S.020
# El precio actual es: 279.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 265.05 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/6bc478bd-be79-480a-80df-c4ccf59b8160/08215038.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/American-Standard-Edgemere-White-WaterSense-Elongated-Chair-Height-2-Piece-Toilet-12-in-Rough-In-Size/1000241449
# La marca es la: American Standard
# El sanitario es el: Edgemere Elongated CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 1000241449
# El item es el: 806369
# El model es el: 765AA101.020
# El precio actual es: 189.0 USD
# El precio anterior es: 219.0 USD
# El precio con descuento especial es: 179.55 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/7f79fd1d-b7bb-4287-86fd-42117ce5be1a/07944774.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Project-Source-Project-Source-Pro-Flush-2-Piece-Single-Flush-Elongated-Chair-Height-White-1-28-GPF/1003066162
# La marca es la: Project Source
# El sanitario es el: Pro-flush Elongated CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 1003066162
# El item es el: 2691714
# El model es el: MT-802PRO
# El precio actual es: 99.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 94.05 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/365a050a-ee4b-4098-8e25-22cdb2c67aed/16414656.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/KOHLER-Memoirs-White-WaterSense-Elongated-Chair-Height-2-Piece-Toilet-12-in-Rough-In-Size/50057975
# La marca es la: KOHLER
# El sanitario es el: Memoirs Elongated CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 50057975
# El item es el: 335319
# El model es el: 98994-0
# El precio actual es: 399.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 379.05 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/5a74e0fb-7df0-4185-9f68-f38321224b2d/02960140.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Project-Source-Project-Source-Pro-Flush-Single-Flush-12in-Rough-In-2-Piece-Chair-Height-Round-Bowl-1-28-GPF-White/1003140864
# La marca es la: Project Source
# El sanitario es el: Pro-flush Round Front CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 1003140864
# El item es el: 2743133
# El model es el: MT-803PRO
# El precio actual es: 99.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 94.05 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/86203021-56a1-4d20-8607-584d0cd25cbf/16611066.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Project-Source-Project-Source-Pro-Flush-Dual-Flush-12in-Rough-In-2-Piece-Chair-Height-Elongated-Bowl-1-1-1-6-GPF-Dual-Flush-White/1003140866
# La marca es la: Project Source
# El sanitario es el: Pro-flush Elongated CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 1003140866
# El item es el: 2743134
# El model es el: MT-20204P
# El precio actual es: 99.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 94.05 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/7b6da649-3a60-4634-9ccf-b7ec55ce7544/16611071.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/KOHLER-Transpose-White-WaterSense-Elongated-Comfort-Height-2-Piece-Toilet-12-in-Rough-In-Size-ADA-Compliant/5001837263
# La marca es la: KOHLER
# El sanitario es el: Transpose Elongated CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 5001837263
# El item es el: 2691532
# El model es el: 46018-0
# El precio actual es: 349.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 331.55 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/d263985d-0f2e-4b7b-9472-6eaae93b9e79/40906882.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/KOHLER-Highline-Curve-White-Round-Comfort-Height-2-piece-Toilet-12-in-Rough-In-Size/1001097310
# La marca es la: KOHLER
# El sanitario es el: Highline Round Front CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 1001097310
# El item es el: 1323430
# El model es el: K-30369-0
# El precio actual es: 199.0 USD
# El precio anterior es: 219.0 USD
# El precio con descuento especial es: 189.05 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/f6f76223-af93-4321-a529-e901a44ecff2/11255256.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Project-Source-Project-Source-Laporte-Dual-Flush-12in-Rough-In-1-Piece-Chair-Height-Elongated-Bowl-1-1-1-6-GPF-Dual-Flush-White/5000046183
# La marca es la: Project Source
# El sanitario es el: Laporte Elongated CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 5000046183
# El item es el: 2743136
# El model es el: MT-20102P
# El precio actual es: 169.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 160.55 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/826c8f93-83a4-4c45-b536-6218030f9538/17122481.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/KOHLER-Elliston-White-WaterSense-Elongated-Comfort-Height-2-piece-Toilet-12-in-Rough-In-Size/1001354516
# La marca es la: KOHLER
# El sanitario es el: Elliston Elongated CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 1001354516
# El item es el: 461992
# El model es el: K-31120-0
# El precio actual es: 199.0 USD
# El precio anterior es: 269.0 USD
# El precio con descuento especial es: 189.05 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/e45b2679-1bbc-4f0d-a5db-bcbe21c945e4/12186373.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/KOHLER-Cimarron-White-WaterSense-Round-Comfort-Height-2-Piece-Toilet-12-in-Rough-In-Size-ADA-Compliant/5001965759
# La marca es la: KOHLER
# El sanitario es el: Cimarron Round Front CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 5001965759
# El item es el: 3629217
# El model es el: 31678-0
# El precio actual es: 269.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 255.55 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/4ec0425e-ef3a-4986-905c-93e2d22e110b/42700503.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/American-Standard-Mainstream-White-WaterSense-Elongated-Chair-Height-2-Piece-Toilet-12-in-Rough-In-Size-ADA-Compliant/5001899855
# La marca es la: American Standard
# El sanitario es el: Mainstream Elongated CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 5001899855
# El item es el: 3637695
# El model es el: 734AA101.020
# El precio actual es: 169.0 USD
# El precio anterior es: 189.0 USD
# El precio con descuento especial es: 160.55 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/dc3c5eb7-f412-48bb-9224-fdca4aa12f7a/41860305.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/American-Standard-Mainstream-White-WaterSense-Round-Chair-Height-2-Piece-Toilet-12-in-Rough-In-Size/3286026
# La marca es la: American Standard
# El sanitario es el: Mainstream Round Front CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 3286026
# El item es el: 291379
# El model es el: 3472.128.020
# El precio actual es: 159.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 151.05 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/dc6bcdb5-7eb0-4ec7-9633-80dbf69934ce/00627144.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/American-Standard-Clean-White-WaterSense-Dual-Flush-Elongated-Chair-Height-2-Piece-Toilet-12-in-Rough-In-Size/1000252663
# La marca es la: American Standard
# El sanitario es el: Clean White Elongated CTK Standard
# El tipo de producto es un: CTK
# El sku es el: 1000252663
# El item es el: 543603
# El model es el: 721AA200S.020
# El precio actual es: 309.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 293.55 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/c2b24171-3163-432c-b53f-87abcdcf445d/08243022.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/American-Standard-Mainstream-White-WaterSense-Elongated-Chair-Height-Toilet-12-in-Rough-In-Size-ADA-Compliant/5001891457
# La marca es la: American Standard
# El sanitario es el: Mainstream Elongated CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 5001891457
# El item es el: 3637696
# El model es el: 753AA101.020
# El precio actual es: 299.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 284.05 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/94a31fa1-7378-4046-93be-fc866f00f2ae/41970265.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/American-Standard-Champion-White-WaterSense-Round-Chair-Height-2-piece-Toilet-12-in-Rough-In-Size/1000251039
# La marca es la: American Standard
# El sanitario es el: Champion Round Front CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 1000251039
# El item es el: 615478
# El model es el: 731BA101S.020
# El precio actual es: 249.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 236.55 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/fe3f5160-f981-4fbc-b03d-04cff7c05a3a/08236462.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/KOHLER-Memoirs-White-WaterSense-Chair-Height-2-piece-Toilet-12-in-Rough-In-Size/3343296
# La marca es la: KOHLER
# El sanitario es el: Memoirs Elongated CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 3343296
# El item es el: 335319
# El model es el: 10494-0
# El precio actual es: 399.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 379.05 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/494dcebb-6ca0-4685-869f-0d95372ca053/00668988.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Project-Source-Project-Source-Danville-Single-Flush-12in-Rough-In-2-Piece-Chair-Height-Elongated-Bowl-1-28-GPF-Oyster/5000026211
# La marca es la: Project Source
# El sanitario es el: Danville Elongated CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 5000026211
# El item es el: 2743138
# El model es el: MT-20202MP
# El precio actual es: 169.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 160.55 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/bbc8c90a-6d2f-4c7a-b687-46c0128e25b4/17077928.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/American-Standard-Edgemere-White-WaterSense-Elongated-Chair-Height-2-Piece-Toilet-10-in-Rough-In-Size/1000241455
# La marca es la: American Standard
# El sanitario es el: Edgemere Elongated CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 1000241455
# El item es el: 806372
# El model es el: 765AB101.020
# El precio actual es: 229.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 217.55 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/c1bab4ca-9bfd-42eb-b527-d38a82722b66/07944767.png
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/American-Standard-Edgemere-White-WaterSense-Round-Chair-Height-2-Piece-Toilet-12-in-Rough-In-Size/1000241451
# La marca es la: American Standard
# El sanitario es el: Edgemere Round Front CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 1000241451
# El item es el: 806370
# El model es el: 765BA101.020
# El precio actual es: 169.0 USD
# El precio anterior es: 189.0 USD
# El precio con descuento especial es: 160.55 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/03a9a96d-ac02-4fe8-9aac-8bd355f73bea/07944785.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/American-Standard-Edgemere-White-WaterSense-Round-Chair-Height-2-Piece-Toilet-10-in-Rough-In-Size/1000241457
# La marca es la: American Standard
# El sanitario es el: Edgemere Round Front CTK Standard
# El tipo de producto es un: CTK
# El sku es el: 1000241457
# El item es el: 806373
# El model es el: 765BB101.020
# El precio actual es: 209.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 198.55 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/033330e9-a255-40d4-a22c-7f1bc1428d9e/07944777.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/American-Standard-Champion-4-White-WaterSense-Elongated-Chair-Height-2-piece-Toilet-12-in-Rough-In-Size/4227813
# La marca es la: American Standard
# El sanitario es el: Champion Elongated CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 4227813
# El item es el: 424943
# El model es el: 2793.128NT.020
# El precio actual es: 279.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 265.05 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/b64d42a6-c6a0-40e3-8152-94edff339338/02336203.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/American-Standard-Edgemere-Bone-WaterSense-Elongated-Chair-Height-2-Piece-Toilet-12-in-Rough-In-Size/1000866604
# La marca es la: American Standard
# El sanitario es el: Edgemere Elongated CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 1000866604
# El item es el: 1170087
# El model es el: 765AA101.021
# El precio actual es: 249.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 236.55 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/98204444-0196-4c2e-8138-a6ea0a5aea88/10118812.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/Project-Source-Project-Source-Danville-Single-Flush-12in-Rough-In-2-Piece-Chair-Height-Elongated-Bowl-1-28-GPF-White/5000026209
# La marca es la: Project Source
# El sanitario es el: Danville Elongated CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 5000026209
# El item es el: 2743137
# El model es el: MT-20202P
# El precio actual es: 149.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 141.55 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/bd673523-fe6b-442d-b68e-d7f2a284d76e/17077918.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/American-Standard-Edgemere-Spalet-EL-CH-White-1-28-GPF-Toilet/5001900105
# La marca es la: American Standard
# El sanitario es el: Edgemere Elongated CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 5001900105
# El item es el: 3637698
# El model es el: 765AA701.020
# El precio actual es: 318.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 302.1 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/5435831b-ff21-4d16-b1b2-3a4bb60d7aec/42575299.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/American-Standard-White-WaterSense-Touchless-Flush-Elongated-Chair-Height-2-Piece-Toilet-12-in-Rough-In-Size-ADA-Compliant/5001915775
# La marca es la: American Standard
# El sanitario es el: Watersense Elongated CTK ADA
# El tipo de producto es un: CTK
# El sku es el: 5001915775
# El item es el: 3637697
# El model es el: 780AA709.020
# El precio actual es: 289.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 274.55 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/4556a906-2662-4423-a50d-a3278a9d4ef8/41970305.jpg
#
#
# Intento numero 0
# <Response [200]>
# Recopilando la información de https://www.lowes.com/pd/American-Standard-Champion-Linen-WaterSense-Elongated-Comfort-Height-2-Piece-Toilet-12-in-Rough-In-Size/1000252665
# La marca es la: American Standard
# El sanitario es el: Champion Elongated CTK Standard
# El tipo de producto es un: CTK
# El sku es el: 1000252665
# El item es el: 543604
# El model es el: 731AA101S.222
# El precio actual es: 339.0 USD
# El precio anterior es:  USD
# El precio con descuento especial es: 322.05 USD
# Inventario:Si
# https://mobileimages.lowes.com/productimages/7c997bed-4d40-4da7-8aa1-10cbde9ddc60/08243023.jpg

# %% [markdown]
# ## Testing API

# %%
import requests, json
from urllib.parse import urlencode


# Tell scraper to use Scraper API as the proxy
API_KEY = 'd9d061ea3ad19b7f0eb56c83f416ba06'

product_id = 5002186849 # Mansfield  Alto White Round Chair Height 2-piece
store_location_id = 2348  # Central Charlotte lowe's

url = f"https://www.lowes.com/PricingServices/price/balance?productId={product_id}&storeNumber={store_location_id}" 

params = {'api_key': API_KEY, 'url': url, "country_code": "us"}

headers = {
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:88.0) Gecko/20100101 Firefox/88.0",
}


#r = requests.get(url, headers=headers, timeout=5)
r = requests.get('http://api.scraperapi.com/', params=urlencode(params))

print("return code:", r)
print("content length:", len(r.content))
print(json.dumps(json.loads(r.text), indent=True))

# %%
import requests

# set up the request parameters
params = {
  'api_key': 'demo',
  'item_id': '5002186849'
}

# make the http GET request to Backyard API
api_result = requests.get('https://api.backyardapi.com/request', params)

# print the JSON response from Backyard API
print(json.dumps(api_result.json()))

# %% [markdown]
# ## Testing new way SCRAPY

# %%
# Python project for pricing scripping of different sites
# Creado por: Juan Monsalvo

# FOR Lowes
# ----------------------------------------------------------------------------------------------------------------------
# Libraries import
# ----------------------------------------------------------------------------------------------------------------------
import scrapy
from scrapy.http import Request
import requests
import pandas as pd


class LowesSpider(scrapy.Spider):
    name = 'lowes'
    def start_requests(self):

        start_urls = ['https://www.lowes.com/pd/Mansfield-Alto-174-1-28-Round-SmartHeight-8482-Toilet-Combination/5002186849']

        for url in start_urls:
            yield Request(url,
                        headers={'Cookie': 'sn=2348;'}, #Preset a location
                        meta={'dont_merge_cookies': True, #Allows location cookie to get through
                        'url':url}) #Using to get the product SKU

    def parse(self, response):
        saleprice = response.css('span[itemprop="price"]::attr(content)').extract_first()
        wasprice_text = response.css('span.art-pd-wasPriceLbl::text').extract_first()
        if "$" in wasprice_text:
            fullprice =  wasprice_text.split("$")[-1]

        item["productPrice"] = offered_price
        yield item

# %% [markdown]
# # Connection retriving

# %%
# !curl ipecho.net/plain
# Out:
# 34.135.43.220

# %%
import json
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import requests

headers = {
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:88.0) Gecko/20100101 Firefox/88.0",
}

rr = requests.get('http://www.showmyip.com', headers=headers)
soup = BeautifulSoup(rr.content, "html.parser")

ip_d = soup.find('h2', {'id':'ipv4'}).text
ipv4_c = soup.find('table', class_ = 'iptab').find_all('td')[1].text
country_c = soup.find('table', class_ = 'iptab').find_all('td')[5].text
region_c = soup.find('table', class_ = 'iptab').find_all('td')[7].text
city_c = soup.find('table', class_ = 'iptab').find_all('td')[9].text
organization_c = soup.find('table', class_ = 'iptab').find_all('td')[17].text
AS_number_and_name_c = soup.find('table', class_ = 'iptab').find_all('td')[19].text

datos = {'ipv4':ipv4_c,
      'country':country_c,
      'region':region_c,
      'city':city_c,
      'organization':organization_c,
      'as_number_as_name':AS_number_and_name_c   
}

print(datos)
# Out:
# {'ipv4': '34.75.29.50', 'country': 'United States', 'region': 'South Carolina', 'city': 'North Charleston', 'organization': 'Google Cloud (us-east1)', 'as_number_as_name': 'AS396982 Google LLC'}

# %% [markdown]
# # Pip Install

# %%
# !pip install scrapy
# !pip install selenium
# !pip install selenium-wire
# !pip install webdriver-manager
# !apt-get update # to update ubuntu to correctly run apt install
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
import sys
sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')

# %%
# !pip install scrapy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scrapy
#   Downloading Scrapy-2.6.3-py2.py3-none-any.whl (264 kB)
#      |████████████████████████████████| 264 kB 5.6 MB/s
# Collecting pyOpenSSL>=21.0.0
#   Downloading pyOpenSSL-22.1.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 4.7 MB/s
# Requirement already satisfied: lxml>=3.5.0 in /usr/local/lib/python3.7/dist-packages (from scrapy) (4.9.1)
# Collecting Twisted>=18.9.0
#   Downloading Twisted-22.8.0-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 31.8 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from scrapy) (57.4.0)
# Collecting tldextract
#   Downloading tldextract-3.4.0-py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 2.2 MB/s
# Collecting PyDispatcher>=2.0.5
#   Downloading PyDispatcher-2.0.6.tar.gz (38 kB)
# Collecting service-identity>=18.1.0
#   Downloading service_identity-21.1.0-py2.py3-none-any.whl (12 kB)
# Collecting w3lib>=1.17.0
#   Downloading w3lib-2.0.1-py3-none-any.whl (20 kB)
# Collecting zope.interface>=5.0.0
#   Downloading zope.interface-5.4.0-cp37-cp37m-manylinux2010_x86_64.whl (251 kB)
#      |████████████████████████████████| 251 kB 40.1 MB/s
# Collecting parsel>=1.5.0
#   Downloading parsel-1.6.0-py2.py3-none-any.whl (13 kB)
# Collecting itemloaders>=1.0.1
#   Downloading itemloaders-1.0.6-py3-none-any.whl (11 kB)
# Collecting protego>=0.1.15
#   Downloading Protego-0.2.1-py2.py3-none-any.whl (8.2 kB)
# Collecting cryptography>=3.3
#   Downloading cryptography-38.0.1-cp36-abi3-manylinux_2_24_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 44.4 MB/s
# Collecting itemadapter>=0.1.0
#   Downloading itemadapter-0.7.0-py3-none-any.whl (10 kB)
# Collecting queuelib>=1.4.2
#   Downloading queuelib-1.6.2-py2.py3-none-any.whl (13 kB)
# Collecting cssselect>=0.9.1
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=3.3->scrapy) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=3.3->scrapy) (2.21)
# Collecting jmespath>=0.9.5
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: six>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from parsel>=1.5.0->scrapy) (1.15.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.7/dist-packages (from service-identity>=18.1.0->scrapy) (22.1.0)
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.7/dist-packages (from service-identity>=18.1.0->scrapy) (0.4.8)
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.7/dist-packages (from service-identity>=18.1.0->scrapy) (0.2.8)
# Collecting constantly>=15.1
#   Downloading constantly-15.1.0-py2.py3-none-any.whl (7.9 kB)
# Collecting Automat>=0.8.0
#   Downloading Automat-20.2.0-py2.py3-none-any.whl (31 kB)
# Collecting hyperlink>=17.1.1
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#      |████████████████████████████████| 74 kB 3.2 MB/s
# Requirement already satisfied: typing-extensions>=3.6.5 in /usr/local/lib/python3.7/dist-packages (from Twisted>=18.9.0->scrapy) (4.1.1)
# Collecting incremental>=21.3.0
#   Downloading incremental-21.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: idna>=2.5 in /usr/local/lib/python3.7/dist-packages (from hyperlink>=17.1.1->Twisted>=18.9.0->scrapy) (2.10)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from tldextract->scrapy) (3.8.0)
# Collecting requests-file>=1.4
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from tldextract->scrapy) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->tldextract->scrapy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->tldextract->scrapy) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->tldextract->scrapy) (1.24.3)
# Building wheels for collected packages: PyDispatcher
#   Building wheel for PyDispatcher (setup.py) ... done
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.6-py3-none-any.whl size=11958 sha256=583d8fec4c71659e2748a4ead02856c6dd0abaa0cd8c24eb6401caa10b0570a3
#   Stored in directory: /root/.cache/pip/wheels/c9/d6/6a/de198d890277cde60ca3dbebe7ae592d3b381c7d9bb2455f4d
# Successfully built PyDispatcher
# Installing collected packages: w3lib, cssselect, zope.interface, requests-file, parsel, jmespath, itemadapter, incremental, hyperlink, cryptography, constantly, Automat, Twisted, tldextract, service-identity, queuelib, pyOpenSSL, PyDispatcher, protego, itemloaders, scrapy
# Successfully installed Automat-20.2.0 PyDispatcher-2.0.6 Twisted-22.8.0 constantly-15.1.0 cryptography-38.0.1 cssselect-1.1.0 hyperlink-21.0.0 incremental-21.3.0 itemadapter-0.7.0 itemloaders-1.0.6 jmespath-1.0.1 parsel-1.6.0 protego-0.2.1 pyOpenSSL-22.1.0 queuelib-1.6.2 requests-file-1.5.1 scrapy-2.6.3 service-identity-21.1.0 tldextract-3.4.0 w3lib-2.0.1 zope.interface-5.4.0
